# %% [markdown]
# # Web scraping with BeautifulSoup
#
#
#
# ### Import BeautifulSoup
#
# First off, you will need to import the BeautifulSoup library. BS is not part of the Python standard library (i.e. it needs to be installed separately).

# %%
# import beautiful soup library
from bs4 import BeautifulSoup

# %% [markdown]
# To work with BeautifulSoup, you first require some HTML. HTML can either be loaded from a locally stored file, or it can be \`requested' from a web server over HTTP.
# To use the second approach, we will utilise another Python library called `requests`, which is able to make and handle HTTP requests and responses.

# %%
# import requests library
import requests

# %% [markdown]
# We can use the get method in the requests library to retrieve an HTTP response object. An HTTP request contains header fields which may give the server some additional information about the request. One of the fields is called, `user-agent', and it tells the server what software is making the request on behalf of the user. It may be a good idea to set this header, to try to `fool' the server into believing the request is coming via a browser.
#
# The response object has a property, text, which contains the HTML that was sent in the response.
#
# In the following example, we can grab the Coursera homepage code. For these labs you will only be able to grab Coursera resources - if you want to explore other exercises you will have to run Jupyter on your own machine!

# %%
# set a user-agent to be sent with request
#headers = {
#    "user-agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36"
#}
# request a resource from a specific URL. Change this for your chosen website.
r  = requests.get("https://www.coursera.org/")#,headers)

# put the text that is returned in the response in a variable
data = r.text

# look...some HTML has been sent in the response!
data
# Out:
# '<!DOCTYPE html><html lang="en" dir="ltr"><head><link rel="preconnect" href="https://d3njjcbhbojbot.cloudfront.net" crossorigin="true"/><link rel="prerender"/><style>@font-face {  font-family: \'coursera-iconfont\';  src: url(\'https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.eot\');  src: url(\'https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.eot\') format(\'embedded-opentype\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.woff\') format(\'woff\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.ttf\') format(\'truetype\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.svg\') format(\'svg\');}@font-face {  font-family: \'OpenSans-Light\';  font-weight: normal;  font-style: normal;  font-display: swap;  src: url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.eot\');  src: local(\'Open Sans Light\'),local(\'OpenSans-Light\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.eot?#iefix\') format(\'embedded-opentype\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-300.woff2\') format(\'woff2\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-300.woff\') format(\'woff\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.ttf\') format(\'truetype\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.svg#OpenSans-Light\') format(\'svg\');}@font-face {  font-family: \'OpenSans\';  font-style: normal;  font-weight: 300;  font-display: swap;  src: url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.eot\');  src: local(\'Open Sans Light\'),local(\'OpenSans-Light\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.eot?#iefix\') format(\'embedded-opentype\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-300.woff2\') format(\'woff2\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-300.woff\') format(\'woff\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.ttf\') format(\'truetype\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.svg#OpenSans-Light\') format(\'svg\');}@font-face {  font-family: \'OpenSans\';  font-style: normal;  font-weight: 400;  font-display: swap;  src: url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Regular.eot\');  src: local(\'Open Sans\'),local(\'OpenSans\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Regular.eot?#iefix\') format(\'embedded-opentype\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-regular.woff2\') format(\'woff2\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-regular.woff\') format(\'woff\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Regular.ttf\') format(\'truetype\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Regular.svg#OpenSans-Regular\') format(\'svg\');}@font-face {  font-family: \'OpenSans\';  font-style: normal;  font-weight: 600;  font-display: swap;  src: url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Semibold.eot\');  src: local(\'Open Sans Semibold\'),local(\'OpenSans-Semibold\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Semibold.eot?#iefix\') format(\'embedded-opentype\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-600.woff2\') format(\'woff2\'),url(\'https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-600.w ...

# %% [markdown]
# The raw HTML is not very easy to work with, because it is in a semantic markup format. We also have lots of other bits of things in here like CSS!
#
# We need to \`parse' the HTML (i.e. split it into its component parts), which will make working with it much easier. For that we will create an object which is an instance of the BeautifulSoup class. The object will be a special kind of data structure. It will contain the HTML, but in a format we can work with.

# %%
from bs4 import BeautifulSoup
# parse the raw HTML into a `soup' object
soup = BeautifulSoup(data, "html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en"><head><link crossorigin="true" href="https://d3njjcbhbojbot.cloudfront.net" rel="preconnect"/><link rel="prerender"/><style>@font-face {  font-family: 'coursera-iconfont';  src: url('https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.eot');  src: url('https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.eot') format('embedded-opentype'),url('https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.woff') format('woff'),url('https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.ttf') format('truetype'),url('https://d3njjcbhbojbot.cloudfront.net/web/bundles/styleguide/icons/fonts/coursera.v26.svg') format('svg');}@font-face {  font-family: 'OpenSans-Light';  font-weight: normal;  font-style: normal;  font-display: swap;  src: url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.eot');  src: local('Open Sans Light'),local('OpenSans-Light'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.eot?#iefix') format('embedded-opentype'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-300.woff2') format('woff2'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-300.woff') format('woff'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.ttf') format('truetype'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.svg#OpenSans-Light') format('svg');}@font-face {  font-family: 'OpenSans';  font-style: normal;  font-weight: 300;  font-display: swap;  src: url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.eot');  src: local('Open Sans Light'),local('OpenSans-Light'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.eot?#iefix') format('embedded-opentype'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-300.woff2') format('woff2'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-300.woff') format('woff'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.ttf') format('truetype'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Light.svg#OpenSans-Light') format('svg');}@font-face {  font-family: 'OpenSans';  font-style: normal;  font-weight: 400;  font-display: swap;  src: url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Regular.eot');  src: local('Open Sans'),local('OpenSans'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Regular.eot?#iefix') format('embedded-opentype'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-regular.woff2') format('woff2'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-regular.woff') format('woff'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Regular.ttf') format('truetype'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Regular.svg#OpenSans-Regular') format('svg');}@font-face {  font-family: 'OpenSans';  font-style: normal;  font-weight: 600;  font-display: swap;  src: url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Semibold.eot');  src: local('Open Sans Semibold'),local('OpenSans-Semibold'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Semibold.eot?#iefix') format('embedded-opentype'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-600.woff2') format('woff2'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans-v17-latin-latinext-cyrillic/opensans-600.woff') format('woff'),url('https://d3njjcbhbojbot.cloudfront.net/web/type/opensans/OpenSans-Semibold.ttf') format('truetype'),url('https:/ ...
#     window.coursera = {};
#     window.appName = 'next';
#     window.locale = 'en';
#     window.requestCountry = 'US';
#   /* eslint-disable no-var */
#   coursera.epicOverrides = (function () {
#     var injectedString = '[{\"namespace\":\"GrowthDiscovery\",\"idForAllocation\":\"1658698317-1625326494217\",\"experimentId\":\"t2uN4Nq_Eeu5VgEitQVwww\",\"variantId\":\"36DGiyz5Qi2V_7ipCsUPwA\",\"parameterName\":\"algoliaIndexTypeToIndexNameMap\",\"id\":0,\"version\":1,\"value\":{\"all\":\"prod_all_products_term_optimization\",\"enterprise_courses\":\"prod_enterprise_courses\",\"courses\":\"test_courses\",\"careers\":\"test_careers\",\"specializations\":\"test_s12ns\",\"projects\":\"prod_projects\",\"enterprise_products\":\"prod_enterprise_products\",\"suggestions\":\"test_suggestions\",\"learning_paths\":\"test_career_plans_learning_paths\",\"degrees\":\"prod_degrees\",\"products\":\"test_products\"},\"status\":\"RUNNING\"},{\"namespace\":\"GrowthAcquisition\",\"idForAllocation\":\"1658698317-1625326494217\",\"experimentId\":\"G0NI4GfZEeqkb6_BL1dowg\",\"variantId\":\"_Y6BS-pQR1CHKLXMcJME0g\",\"parameterName\":\"improveCertificatesOnXDP\",\"id\":1,\"version\":1,\"value\":true,\"status\":\"RUNNING\"},{\"namespace\":\"Enterprise\",\"idForAllocation\":\"1658698317-1625326494217\",\"experimentId\":\"7ntPEDSZEemUF9PO6Co8LA\",\"variantId\":\"w_SpVBXiQj2apN9FAUtmGQ\",\"parameterName\":\"fullStoryAdminDashboardEnabled\",\"id\":2,\"version\":1,\"value\":true,\"status\":\"RUNNING\"},{\"namespace\":\"GrowthDegrees\",\"idForAllocation\":\"1658698317-1625326494217\",\"experimentId\":\"GHGqEJH4EemC3Kv3M-kuwQ\",\"variantId\":\"CBZP85RlRI6zlbJ82HnN8w\",\"parameterName\":\"masterTracksPaidOnCoursera\",\"id\":6,\"version\":1,\"value\":[\"construction-engineering-management-umich\",\"supply-chain-excellence-rutgers\",\"machine-learning-analytics-chicago\",\"innovation-management-entrepreneurship-hec\",\"social-work-umich\",\"sustainability-development-umich\",\"ux-design-minnesota\",\"blockchain-duke\",\"graduate-english-proficiency-asu-cert\",\"data-analytics-managers-tufts\"],\"status\":\"RUNNING\"},{\"namespace\":\"Enterprise\",\"idForAllocation\":\"1658698317-1625326494217\",\"experimentId\":\"r53sIPN_Eeq3Zq2AxGUSNw\",\"variantId\":\"Fksg88GuQ0mmNDJ-uNa--g\",\"parameterName\":\"disableProgramJumbotronContrast\",\"id\":7,\"version\":1,\"value\":[\"XhOW5ZDBRDGRGt4kuEzcHA\",\"Fj2y1dYVSGisNewqgqbsaA\",\"6NUDta5tS7CBIvHMVFPPPQ\",\"6PYhHE8NR5iIntKXgmePZA\",\"3EmqTKAjSZGoalMou97GcQ\",\"jMx9Q85TTrWJavt7uzuuow\"],\"status\":\"RUNNING\"},{\"namespace\":\"GrowthAcquisition\",\"idForAllocation\":\"1658698317-1625326494217\",\"experimentId\":\"CnzQgLjcEeuLYr9doRvLUQ\",\"variantId\":\"2Y0OXtgIQ2iS1U36HyfP1w\",\"parameterName\":\"useCdsOnDirectory\",\"id\":8,\"version\":1,\"value\":true,\"status\":\"RUNNING\"},{\"namespace\":\"GrowthAcquisition\",\"idForAllocation\":\"1658698317-1625326494217\",\"experimentId\":\"9SZqkOmBEeqNTH_1wxkVlg\",\"variantId\":\"ZW9Aj0eITLqd5ikEuFLgXw\",\"parameterName\":\"enableLazyImages\",\"id\":9,\"version\":1,\"value\":false,\"status\":\"RUNNING\"},{\"namespace\":\"GrowthAcquisition\",\"idForAllocation\":\"1658698317-1625326494217\",\"experimentId\":\"n8tYsDj8EeuEwT-ZvGq9iA\",\"variantId\":\"Ke_g_cSZTV2YpmDZCWhMlg\",\"parameterName\":\"androidMinBuildForEnterpriseReCaptcha\",\"id\":11,\"version\":1,\"value\":22537,\"status\":\"RUNNING\"},{\"namespace\":\"Enterprise\",\"idForAllocation\":\"1658698317-1625326494217\",\"experimentId\":\"QQ9c8KMnEeumKumhno_31Q\",\"variantId\":\"oiCiXa1ZRnmVaaPxohZJgA\",\"parameterName\":\"sendTrafficToJavaUserRosters\",\"id\":14,\"version\":1,\"value\":true,\"status\":\"RUNNING\"},{\"namespace\":\"SEO\",\"idForAllocation\":\"1658698317-1625326494217\",\"experimentId\":\"wuviYFL3EeqGr-cZzTH5jQ\",\"variantId\":\"RxB7izCjT8WmgUCFUOCydw\",\"parameterName\":\"addContextualLinksToBrowseAndEntityPages\",\"id\":16,\"version\":1,\"value\":true,\"status\":\"RUNNING\"},{\"namespace\":\"Enterprise\",\"idForAllocation\":\"1658698317-1625326494217\",\"experimentId\":\"t-b7kP2pEeqrs5N3SAZyUw\",\"variantId\":\"t6NUtJCYTmqOw10qMmucYA\",\"parameterName\":\"disableUpswellVerificationStep\",\"id\":17,\"version\":1, ...
#     var epicResponse = injectedString && injectedString !== '' && injectedString !== undefined ?
#         JSON.parse(injectedString) : {};
#     return epicResponse || {};
#   })();
#
#
#     /* globals coursera*/
#     // Defines a named AMD module containing the course ID
#     coursera.courseId = (function () {
#     return 'null';
#     })();
#
#     /* globals coursera */
#     /* eslint-disable quotes */
#     coursera.user = (function () {
#     if (true) {
#         return JSON.parse('{}');
#     } else {
#         return {};
#     }
#     })();
#
#     window.coursera.config = (function () {
#         if (true) {
#             //- web request's country of origin, injected by Edge as ISO 3166-1 alpha-2
#             var config = JSON.parse('{\"gapi_eventing_data\":{\"project_number\":\"274249572679\",\"api_key\":\"\",\"client_id\":\"274249572679-al8nc3ttcavj0n91due232a3h6s3r9vk.apps.googleusercontent.com\"},\"bigquery\":{\"dataset\":\"mydataset\",\"table_prefix\":\"livedata_\"},\"dir\":{\"home\":\"/\"},\"debug\":false,\"compress\":true,\"optimize\":true,\"environment\":\"production\",\"log\":\"error\",\"url\":{\"api\":\"/maestro/api/\",\"maestro\":\"/maestro/api/\",\"base\":\"https://www.coursera.org/\",\"origin\":\"https://www-origin.coursera.org/\",\"cloudfront_api\":\"https://d1hpa2gdx2lr6r.cloudfront.net/maestro/api/\",\"accounts\":\"https://accounts.coursera.org/\",\"assets\":\"https://d3njjcbhbojbot.cloudfront.net/web/\",\"assets_domain\":\"https://d3njjcbhbojbot.cloudfront.net\",\"resource_assets\":\"https://coursera_assets.s3.amazonaws.com/\",\"app_assets\":\"https://d3njjcbhbojbot.cloudfront.net/web/\",\"app_chunks\":\"https://d3njjcbhbojbot.cloudfront.net/webapps/\",\"imageProxyRoot\":\"https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/\"},\"version\":\"1b13274ce36b334f0368908045b11f4bb40577f9\",\"versionTimestamp\":\"1625184909462\"}')
#             config.requestCountryCode = 'US';
#             return config;
#         } else {
#             return {};
#         }
#         })();
#
# </script><script>
#       function generateUUID() {
#         let d = new Date().getTime();
#         const uuid = 'xxxxxxxx-xxxx-4xxx-yxxx-xxxxxxxxxxxx'.replace(/[xy]/g, function (c) {
#           const r = (d + Math.random() * 16) % 16 | 0;
#           d = Math.floor(d / 16);
#           return (c === 'x' ? r : (r & 0x7) | 0x8).toString(16);
#         });
#         return uuid;
#       };
#
#       var eventData = [
#         'key=web.preload.loaded',
#         'clientType=web',
#         'url=' + window.location.href,
#         'value={"appName":"next"}',
#         'app=phoenix',
#         'screenSize=' + '{"height":' + window.innerHeight + ', "width":' + window.innerWidth + '}',
#         'clientVersion=' + (window.coursera && window.coursera.config && window.coursera.config.version) || '',
#         'clientTimestamp=' + Date.now(),
#         'visitId=' + generateUUID(),
#         'guid=' + generateUUID()
#       ];
#
#       var request = new XMLHttpRequest();
#       request.open('POST', 'https://www.coursera.org/eventing/info.v2');
#       request.setRequestHeader("Content-Type", "application/x-www-form-urlencoded");
#       request.send(encodeURI(eventData.join('&')));
#     </script><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><meta content="Coursera" property="og:site_name"/><meta content="727836538,4807654" property="fb:admins"/><meta content="823425307723964" property="fb:app_id"/><meta content="Coursera" name="twitter:site"/><meta content="Coursera" name="twitter:app:name:iphone"/><meta content="Coursera" name="twitter:app:name:ipad"/><meta content="Coursera" name="twitter:app:name:googleplay"/><meta content="id736535961" name="twitter:app:id:iphone"/><meta content="id736535961" name="twitter:app:id:ipad"/><meta content="org.coursera.android" name="twitter:app:id:googleplay"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/favicon.ico" rel="shortcut icon"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-60x60.png" rel="apple-touch-icon" sizes="60x60"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-76x76.png" rel="apple-touch-icon" sizes="76x76"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/apple-touch-icon-v2-180x180.png" rel="apple-touch-icon" sizes="180x180"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/favicon-v2-194x194.png" rel="icon" sizes="194x194" type="image/png"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/android-chrome-v2-192x192.png" rel="icon" sizes="192x192" type="image/png"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/favicon-v2-96x96.png" rel="icon" sizes="96x96" type="image/png"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/favicon-v2-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="https://d3njjcbhbojbot.cloudfront.net/web/images/favicons/favicon-v2-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link as="font" crossorigin="true" href="https://d3njjcbhbojbot.cloudfront.net/web/type/source-sans-pro-v14-latin/source-sans-pro-v14-latin-regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="true" href="https://d3njjcbhbojbot.cloudfront.net/web/type/source-sans-pro-v14-latin/source-sans-pro-v14-latin-600.eot" rel="preload" type="font/woff2"/><link as="font" crossorigin="true" href="https://d3njjcbhbojbot.cloudfront.net/web/type/source-sans-pro-v14-latin/source-sans-pro-v14-latin-700.eot" rel="preload" type="font/woff2"/><title>Coursera | Build Skills with Online Courses from Top Institutions</title><meta content="Join Coursera for free and learn online. Build skills with courses from top universities like Yale, Michigan, Stanford, and leading companies like Google and IBM. Advance your career with degrees, certificates, Specializations, &amp;amp; MOOCs in data science, computer science, business, and dozens of other topics." name="description"/><meta content="https://s3.amazonaws.com/coursera/media/Grid_Coursera_Partners_updated.png" name="image"/><meta content="Coursera | Build Skills with Online Courses from Top Institutions" property="og:title"/><meta content="Join Coursera for free and learn online. Build skills with courses from top ...
# <script type="application/ld+json">
#           {"@context":"http://schema.org","@id":"https://www.coursera.org/#organization","@type":"Organization","name":"Coursera","url":"https://www.coursera.org/","logo":"https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera.s3.amazonaws.com/media/coursera-rebrand-logo-square.png?auto=format%2Ccompress&dpr=1","sameAs":["https://www.wikidata.org/wiki/Q499962","https://www.instagram.com/coursera/","https://www.youtube.com/user/coursera","https://twitter.com/coursera","https://www.linkedin.com/company/coursera","https://www.facebook.com/Coursera"]}
#         </script>
# </div></div></div><script id="__NEXT_DATA__" type="application/json">{"props":{"pageProps":{"namespacesRequired":["page","seo","common","authentication","phoenix","growth-upsell","coursera-ui","design-system","front-page","page-header","search","user-account","megamenu"],"seoOverrideRule":[{"pathName":"www.coursera.org","disableCrawlerIndexing":false,"title":"Coursera | Build Skills with Online Courses from Top Institutions","description":"Join Coursera for free and learn online. Build skills with courses from top universities like Yale, Michigan, Stanford, and leading companies like Google and IBM. Advance your career with degrees, certificates, Specializations, \u0026amp; MOOCs in data science, computer science, business, and dozens of other topics.","canonicalLinkHrefOverride":"https://www.coursera.org/"},{"pathName":"www.coursera.org/","disableCrawlerIndexing":false,"title":"Coursera | Build Skills with Online Courses from Top Institutions","description":"Join Coursera for free and learn online. Build skills with courses from top universities like Yale, Michigan, Stanford, and leading companies like Google and IBM. Advance your career with degrees, certificates, Specializations, \u0026amp; MOOCs in data science, computer science, business, and dozens of other topics.","canonicalLinkHrefOverride":"https://www.coursera.org/"}],"regionSlug":"us","isPreview":false,"variant":"Control"},"cookies":{"__204u":"1658698317-1625326494217","CSRF3-Token":"1626190494.3VXlMrGtGCCuCqj9"},"ssrRouterData":{"pathname":"/","query":{},"search":""},"userAgentApi":{"source":"python-requests/2.23.0","browser":{"name":"unknown"},"system":"unknown","platform":"unknown","isMobileBrowser":false,"isAndroid":false,"isCourseraMobileApp":false,"isMobile":false,"isIOS":false,"isMobilePhoneBrowser":false,"isPrerender":false,"isRobot":false},"requestCountryCode":"US","csrfToken":false,"apolloClient":null,"initialApolloState":{"$ROOT_QUERY.loggedOutHomePageContentCollection({\"limit\":1,\"locale\":\"en-US\",\"preview\":false,\"where\":{\"regionSlug\":\"us\"}}).items.0":{"regionSlug":"us","promoBannerId":"lohp_promo_c4c_2021","promoBannerText":"Free learning resources [For Universities](/campus/basic?utm_campaign=website\u0026utm_content=c4cf-top-banner-dotorg\u0026utm_medium=coursera\u0026utm_source=home-page) and [For College Students](/for-university-and-college-students?utm_source=home-page\u0026utm_medium=coursera\u0026utm_campaign=Mar2020-coursera-together\u0026utm_content=c4cv-top-banner-dotorg-3)","hero":{"type":"id","generated":true,"id":"$ROOT_QUERY.loggedOutHomePageContentCollection({\"limit\":1,\"locale\":\"en-US\",\"preview\":false,\"where\":{\"regionSlug\":\"us\"}}).items.0.hero","typename":"MarketingContent"},"goalsValuePropsTitle":"Achieve your goals with Coursera","goalsValuePropOpen1":"Learn the\nlatest skills","goalsValuePropClose1":"like business analytics, graphic design, Python, and more","goalsValuePropOpen2":"Get ready\nfor a career","goalsValuePropClose2":"in high-demand fields like IT, AI and cloud engineering","goalsValuePropOpen3":"Earn\na degree","goalsValuePropClose3":"from a leading university in business, computer science, and more","goalsValuePropOpen4":"Upskill your\norganization","goalsValuePropClose4":"with on-demand training and development programs","__typename":"LoggedOutHomePageContent","outcomes":{"type":"id","generated":true,"id":"$ROOT_QUERY.loggedOutHomePageContentCollection({\"limit\":1,\"locale\":\"en-US\",\"preview\":false,\"where\":{\"regionSlug\":\"us\"}}).items.0.outcomes","typename":"MarketingContent"},"outcomesC4BCtaText":"Try Coursera for Business","outcomesFootnote":"Coursera Learner Outcomes Survey (2019)","c4BTitle":"Coursera for Business","c4BText":"Weâve got the solution: world-class training and development programs developed by top universities and companies. All on Coursera for Business.","c4BEnterpriseCtaText":"Coursera for Enterprise","c4BPartnersLogosCollection":{"type":"id","generated":true,"id ...
#                   window.__REHYDRATE_APHRODITE_IDS = ["_1l1hu98","_pu0m129","_1j095b7","_xcrq5m","_r3zeoj","_fvd8ru","_1qqkmv","_473mf9o","_e296pg","keyframe_1mfzdnn","_1hwtb43","_r9yt7q","_41qsc","_l3lqkfz","_1lutnh9y","_ufjrdd","_1t9pzbn","_1bmi48h","_egfx4z","_c4ecak","_tocnv8","_1dru2k9","_1rrvnfw","_1sqmgk0h","_1m3k1gr","_61ccwn","_1joqcnb","_67717r","_1v53p9m","_18ozdrj","_gxigg9","_ajqms8","_1dvzwtw","_pwpms2","_10eziy5","_d8t0vt","_1vri9u7","_pklhv3","_yoza43","_154i90e","_laqrpf","_yyncah","_jk6cph","_gyvd0s","_1lwxvya","_n5iiiv","_gtp2q1","_1d2l3eb","_hgqut1","_huqwne","_qdw02k","_12hdj83","_16p6c6d","_1nhfz2","_1tk286il","_1vhrodh","_b78otlk","_19v39nf","_13zd3uf","_1m5vqgo","_p9rylm","_1ntfkf","_25ge1o","_ot33op","_1cp26mw","_1a7sdmu","_tbk8n4","_atn7s2","_7plnu5f","_979aq6","_16fabyg","_1403gtl","_1kn0h4a","_1dd4mq0","_1xf3hcz","_ynkimw","_97f7t9","_qtlt7o","_1ymmwi","_irgnui","_1829r4g","_fw6x9h","_1spgmms","_l9xvgl","_19688v4","_la2453","_15ljpe2","_lzz9kt","_g9ej6l","_nwb266","_bnbnx2","_p6jd8e","_12zrx6i","_he0eg1","_1sjwac4","_1p1byfm","_17a1k1u","_1o0ckqn","_dlod29","_11mzu6","_1xjp0u4","_13prlk8","_ukugut","_a18gsp","_np8wi","_fd0tib","_l9zk11","_174baii","_zvg2yu","_fpredl","_1s8rt72","_1lwkob4","_192jy1b","_1qj14mg","_yusei2","_kze5iu","_gtlhfa","_q13m3u","_12dikri","_1wndf9f","_jyhj5r","_1vbo4s","_6zvbayr","_pebu3zt","_wwcfwz","_8ekd2y","_181t6pv","_liimpa"]
#                 </script></body></html>

# %% [markdown]
# Now that we have parsed the HTML, we can call methods of the BeautifulSoup class to access specific elements in the data.
#
# ### Extract a single element by tag name
# For example, the `find` method will return the first available element with a specified tag name:

# %%
h1 = soup.find("h1")
print(h1)
# If you can't find the h1 element you might want to right click the page and view source. See if you can identify 
# an element you can scrape e.g. <p> tags <img> tags or links <a href="">
# Out:
# <h1 class="_c4ecak">Learn Without Limits</h1>

# %% [markdown]
# ### Extract all of a certain element by tag name
# The `find_all` method will return all the elements of a certain type:

# %%
# get all the th elements 
# e.g. for a table we could say
# table = soup.find_all("table")
text = soup.find_all("p")

# Not all web pages will have tables, p tags or classes. Markup is dependent on what the person building the 
# webpage decided should appear.
print(text)
# Out:
# [<p class="_tocnv8">Build skills with courses, certificates, and degrees online from world-class universities and companies.</p>, <p class="_ynkimw">77+ million people are already learning on Coursera</p>, <p class="_l9xvgl">Take the next step toward your personal and professional goals with Coursera.</p>, <p class="_12zrx6i">Weâve got the solution: world-class training and development programs developed by top universities and companies. All on Coursera for Business.</p>, <p class="_17a1k1u"><span class="_1o0ckqn">2,000+</span><span class="_dlod29">Coursera for Business customers</span></p>, <p class="_zvg2yu">Earn your bachelorâs or masterâs degree online from a leading university for much less than similar on-campus programs. Learn from the same professors and graduate with the same credential as students who study on-campus.</p>, <p class="_q13m3u">Degree</p>, <p class="_12dikri">Master of Business Administration (iMBA)</p>, <p class="_q13m3u">Degree</p>, <p class="_12dikri">Master of Computer Science</p>, <p class="_q13m3u">Degree</p>, <p class="_12dikri">Global Master of Public Health</p>, <p class="_q13m3u">Degree</p>, <p class="_12dikri">Master of Computer Science in Data Science</p>]

# %% [markdown]
# ### Filter elements by attribute
#
# HTML elements can have attributes. These are key-value pairs defined inside the opening tag. For example, a hyperlink (anchor) tag has an href attribute specifying the URL to link to:
#
#         <a href="http://www.somewhereoutthere.com">This is not a real URL!</a>
#
# We can be more specific about which elements to retrieve with find all, by including an attribute value:

# %%
# extract all the th elements containing the scope attribute, with the value, `row'
# table = soup.find('table')
# rows = table[0].find_all("tr")
# Let's get the element in our text variable at index 10
elements = text[10]
elements
# Out:
# <p class="_q13m3u">Degree</p>

# %% [markdown]
# ### Filter elements by contents
# We may also decide which elements to extract based on their text contents. For example,

# %%
# extract all th elements containing the string, `Salt'
# energy = table[0].find_all("td",string="Energy ")
# energy
# Can you do this for text[10] or one of the other elements in our text variable?

degr = soup.find_all('p', string = 'Degree')
degr
# Out:
# [<p class="_q13m3u">Degree</p>,
#  <p class="_q13m3u">Degree</p>,
#  <p class="_q13m3u">Degree</p>,
#  <p class="_q13m3u">Degree</p>]

# %% [markdown]
# ### Extract the next sibling element
# We might want to get at the element next to another element.
#
# For example, let's suppose I want the value contained in the `td` element proceding the previous `th`...

# %%
# get the text from the next element after something
# as a table you might do energy[0].findNext("td").text
# or we could do this
elements.findNext("").text
# Out:
# 'Global Master of Public Health'

# %% [markdown]
# # Have a look at the rest of the page
# Does this look easy to scrape? Are there any elements that look confusing or strange?
#
# Select an element on the page and write a line of code that is able to scrape that element. Post your code on the discussion forums and explain how it works. Comment on a post from one of your colleagues and see if you can replicate their web scraping exercise.
#
# You will notice that the page has lots of Javascript generating what we describe as 'dynamic events.' Post your thoughts on the discussion forums regarding:
# <ul><li>What do you think the Javascript is doing?</li>
#     <li>Why do you think it is used/useful?</li>
#     <li>What challenges might you face in web scraping dynamic content?</li>
#     </ul>
# Reply to a post from one of your colleagues and see if you agree with their findings.

# %% [markdown]
# ## Further reading
# For a more detailed introduction to web scraping, you may find this [Webscraping article](https://blog.hartleybrody.com/web-scraping/) by Hartley Brody interesting.
#
# The BeautifulSoup documentation can be found here: [BS Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
